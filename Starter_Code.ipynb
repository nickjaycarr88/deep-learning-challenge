# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %% [markdown]
# The following ten cells are used to explore tha data more and see what type of data is added and how many

# %%
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df["AFFILIATION"].value_counts()
# Out:
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: AFFILIATION, dtype: int64

# %%
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C3700        1
# C1732        1
# C6100        1
# C1728        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
application_df["USE_CASE"].value_counts()
# Out:
# Preservation     28095
# ProductDev        5671
# CommunityServ      384
# Heathcare          146
# Other                3
# Name: USE_CASE, dtype: int64

# %%
application_df["ORGANIZATION"].value_counts()
# Out:
# Trust           23515
# Association     10255
# Co-operative      486
# Corporation        43
# Name: ORGANIZATION, dtype: int64

# %%
application_df["STATUS"].value_counts()
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
application_df["SPECIAL_CONSIDERATIONS"].value_counts()
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
#Drop SPECIAL_CONSIDERATIONS and STATUS as they are over 99% in favour of one output
application_df = application_df.drop(["SPECIAL_CONSIDERATIONS", "STATUS"], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# 0       Association              0      5000              1
# 1      Co-operative         1-9999    108590              1
# 2       Association              0      5000              0
# 3             Trust    10000-24999      6692              1
# 4             Trust  100000-499999    142590              1
# ...             ...            ...       ...            ...
# 34294   Association              0      5000              0
# 34295   Association              0      5000              0
# 34296   Association              0      5000              0
# 34297   Association              0      5000              1
# 34298  Co-operative          1M-5M  36500179              0
#
# [34299 rows x 8 columns]

# %%
application_df["INCOME_AMT"].value_counts()
# Out:
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: INCOME_AMT, dtype: int64

# %%
application_df["ASK_AMT"].value_counts()
# Out:
# 5000       25398
# 10478          3
# 15583          3
# 6725           3
# 63981          3
#            ...
# 772556         1
# 70103          1
# 27096          1
# 25049          1
# 1138700        1
# Name: ASK_AMT, Length: 8747, dtype: int64

# %%
#Save Is SUCCESSFUL to y variable as we will delete from dataframe and use in test/split 
y = application_df["IS_SUCCESSFUL"].values.reshape(-1,1)
y
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [0],
#        [1],
#        [0]], dtype=int64)

# %%
#Drop IS_SUCCESSFUL as it will interfere with the calculation

application_df = application_df.drop(["IS_SUCCESSFUL"], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT   ASK_AMT
# 0       Association              0      5000
# 1      Co-operative         1-9999    108590
# 2       Association              0      5000
# 3             Trust    10000-24999      6692
# 4             Trust  100000-499999    142590
# ...             ...            ...       ...
# 34294   Association              0      5000
# 34295   Association              0      5000
# 34296   Association              0      5000
# 34297   Association              0      5000
# 34298  Co-operative          1M-5M  36500179
#
# [34299 rows x 7 columns]

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# INCOME_AMT             9
# ASK_AMT             8747
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = ['T9','T13','T12','T2','T14','T25','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.head(50)
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
# 15               T3       Independent          C1200  Preservation
# 16               T3       Independent          C2000  Preservation
# 17               T3       Independent          C1000     Heathcare
# 18               T3  CompanySponsored          C1000  Preservation
# 19               T3  CompanySponsored          C1000  Preservation
# 20               T4       Independent          C3000    ProductDev
# 21               T3       Independent          C1200  Preservation
# 22               T3       Independent          C7000  Preservation
# 23               T4  CompanySponsored          C3000    ProductDev
# 24               T3  CompanySponsored          C1200  Preservation
# 25               T4       Independent          C3000    ProductDev
# 26               T3  CompanySponsored          C1000  Preservation
# 27               T3  CompanySponsored          C2000  Preservation
# 28               T3  CompanySponsored          C2000  Preservation
# 29               T6       Independent          C2000    ProductDev
# 30               T6       Independent          C2000    ProductDev
# 31               T3       Independent          C1200  Preservation
# 32               T7       Independent          C1000    ProductDev
# 33               T3  CompanySponsored          C1000  Preservation
# 34               T3       Independent          C1000  Preservation
# 35               T3       Independent          C1200  Preservation
# 36               T4       Independent          C1000    ProductDev
# 37               T3       Independent          C1000  Preservation
# 38               T7       Independent          C1000    ProductDev
# 39               T3       Independent          C1000  Preservation
# 40               T3       Independent          C1000  Preservation
# 41            Other       Independent          C1000    ProductDev
# 42               T7       Independent          C1000    ProductDev
# 43               T3  CompanySponsored          C1000  Preservation
# 44               T3       Independent          C7200  Preservation
# 45               T3       Independent          C1000  Preservation
# 46               T3  CompanySponsored          C2000  Preservation
# 47               T7       Independent          C1000    ProductDev
# 48               T3       Independent          C1700  Preservation
# 49               T3       Independent          C1000  Preservation
#
#     ORGANIZATION     INCOME_AMT   ASK_AMT
# 0    Association              0      5000
# 1   Co-operative         1-9999    108590
# 2    Association              0      5000
# 3          Trust    10000-24999      6692
# 4          Trust  100000-499999    142590
# 5          Trust              0      5000
# 6          Trust  100000-499999     31452
# 7          Trust        10M-50M   7508025
# 8          Trust         1-9999     94389
# 9    Association              0      5000
# 10         Trust    25000-99999     69656
# 11         Trust  100000-499999    165593
# 12   Association              0      5000
# 13         Trust    25000-99999      5301
# 14         Trust              0      5000
# 15         Trust              0      5000
# 16         Trust              0      5000
# 17         Trust           50M+  86380556
# 18         Trust              0      5000
# 19         Trust  100000-499999    376109
# 20         Trust              0      5000
# 21         Trust              0      5000
# 22         Trust  100000-499999    318296
# 23   Association              0      5000
# 24         Trust              0      5000
# 25         Trust              0      5000
# 26         Trust              0      5000
# 27         Trust    25000-99999     44004
# 28         Trust              0      5000
# 29         Trust              0      5000
# 30         Trust  100000-499999    323466
# 31         Trust              0      5000
# 32         Trust              0      5000
# 33         Trust              0      5000
# 34         Trust              0      5000
# 35         Trust              0      5000
# 36         Trust              0      5000
# 37         Trust              0      5000
# 38   Association              0      5000
# 39         Trust    25000-99999      5000
# 40         Trust    25000-99999    709815
# 41         Trust    25000-99999   1329410
# 42         Trust              0      5000
# 43         Trust              0      5000
# 44         Trust              0      5000
# 45         Trust              0      5000
# 46         Trust              0      5000
# 47         Trust              0      5000
# 48         Trust              0      5000
# 49         Trust              0      5000

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C3700        1
# C1732        1
# C6100        1
# C1728        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# put all values in a list
df_unique_values = application_df['CLASSIFICATION'].unique()
len(df_unique_values)
# Out:
# 71

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1000
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x > 1000]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# create a list with values_count over 1000
delete_from_array = ["C1000", "C2000","C1200","C3000", "C2100"]
delete_from_array
# Out:
# ['C1000', 'C2000', 'C1200', 'C3000', 'C2100']

# %%
# remove values from df_unique_values that are in delete_from_array
df_unique_values = [i for i in df_unique_values if i not in delete_from_array]
len(df_unique_values)
# Out:
# 66

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = df_unique_values
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.head(50)
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          Other  Preservation
# 14               T3       Independent          C1000  Preservation
# 15               T3       Independent          C1200  Preservation
# 16               T3       Independent          C2000  Preservation
# 17               T3       Independent          C1000     Heathcare
# 18               T3  CompanySponsored          C1000  Preservation
# 19               T3  CompanySponsored          C1000  Preservation
# 20               T4       Independent          C3000    ProductDev
# 21               T3       Independent          C1200  Preservation
# 22               T3       Independent          Other  Preservation
# 23               T4  CompanySponsored          C3000    ProductDev
# 24               T3  CompanySponsored          C1200  Preservation
# 25               T4       Independent          C3000    ProductDev
# 26               T3  CompanySponsored          C1000  Preservation
# 27               T3  CompanySponsored          C2000  Preservation
# 28               T3  CompanySponsored          C2000  Preservation
# 29               T6       Independent          C2000    ProductDev
# 30               T6       Independent          C2000    ProductDev
# 31               T3       Independent          C1200  Preservation
# 32               T7       Independent          C1000    ProductDev
# 33               T3  CompanySponsored          C1000  Preservation
# 34               T3       Independent          C1000  Preservation
# 35               T3       Independent          C1200  Preservation
# 36               T4       Independent          C1000    ProductDev
# 37               T3       Independent          C1000  Preservation
# 38               T7       Independent          C1000    ProductDev
# 39               T3       Independent          C1000  Preservation
# 40               T3       Independent          C1000  Preservation
# 41            Other       Independent          C1000    ProductDev
# 42               T7       Independent          C1000    ProductDev
# 43               T3  CompanySponsored          C1000  Preservation
# 44               T3       Independent          Other  Preservation
# 45               T3       Independent          C1000  Preservation
# 46               T3  CompanySponsored          C2000  Preservation
# 47               T7       Independent          C1000    ProductDev
# 48               T3       Independent          Other  Preservation
# 49               T3       Independent          C1000  Preservation
#
#     ORGANIZATION     INCOME_AMT   ASK_AMT
# 0    Association              0      5000
# 1   Co-operative         1-9999    108590
# 2    Association              0      5000
# 3          Trust    10000-24999      6692
# 4          Trust  100000-499999    142590
# 5          Trust              0      5000
# 6          Trust  100000-499999     31452
# 7          Trust        10M-50M   7508025
# 8          Trust         1-9999     94389
# 9    Association              0      5000
# 10         Trust    25000-99999     69656
# 11         Trust  100000-499999    165593
# 12   Association              0      5000
# 13         Trust    25000-99999      5301
# 14         Trust              0      5000
# 15         Trust              0      5000
# 16         Trust              0      5000
# 17         Trust           50M+  86380556
# 18         Trust              0      5000
# 19         Trust  100000-499999    376109
# 20         Trust              0      5000
# 21         Trust              0      5000
# 22         Trust  100000-499999    318296
# 23   Association              0      5000
# 24         Trust              0      5000
# 25         Trust              0      5000
# 26         Trust              0      5000
# 27         Trust    25000-99999     44004
# 28         Trust              0      5000
# 29         Trust              0      5000
# 30         Trust  100000-499999    323466
# 31         Trust              0      5000
# 32         Trust              0      5000
# 33         Trust              0      5000
# 34         Trust              0      5000
# 35         Trust              0      5000
# 36         Trust              0      5000
# 37         Trust              0      5000
# 38   Association              0      5000
# 39         Trust    25000-99999      5000
# 40         Trust    25000-99999    709815
# 41         Trust    25000-99999   1329410
# 42         Trust              0      5000
# 43         Trust              0      5000
# 44         Trust              0      5000
# 45         Trust              0      5000
# 46         Trust              0      5000
# 47         Trust              0      5000
# 48         Trust              0      5000
# 49         Trust              0      5000

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# Generate our categorical variable lists

application_df_cat = application_df.dtypes[application_df.dtypes == "object"].index.tolist()
application_df_cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT']

# %%
application_df["APPLICATION_TYPE"].values
# Out:
# array(['T10', 'T3', 'T5', ..., 'T3', 'T5', 'T3'], dtype=object)

# %%
# Check the number of unique values in each column
application_df[application_df_cat].nunique()
# Out:
# APPLICATION_TYPE    9
# AFFILIATION         6
# CLASSIFICATION      6
# USE_CASE            5
# ORGANIZATION        4
# INCOME_AMT          9
# dtype: int64

# %%
application_df_get_dummies = pd.get_dummies(application_df, columns=application_df_cat)
application_df_get_dummies.columns
# Out:
# Index(['ASK_AMT', 'APPLICATION_TYPE_Other', 'APPLICATION_TYPE_T10',
#        'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4',
#        'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7',
#        'APPLICATION_TYPE_T8', 'AFFILIATION_CompanySponsored',
#        'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
#        'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
#        'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200', 'CLASSIFICATION_C2000',
#        'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000', 'CLASSIFICATION_Other',
#        'USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other',
#        'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
#        'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
#        'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M'],
#       dtype='object')

# %%
application_df_get_dummies.columns
# Out:
# Index(['ASK_AMT', 'APPLICATION_TYPE_Other', 'APPLICATION_TYPE_T10',
#        'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3', 'APPLICATION_TYPE_T4',
#        'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6', 'APPLICATION_TYPE_T7',
#        'APPLICATION_TYPE_T8', 'AFFILIATION_CompanySponsored',
#        'AFFILIATION_Family/Parent', 'AFFILIATION_Independent',
#        'AFFILIATION_National', 'AFFILIATION_Other', 'AFFILIATION_Regional',
#        'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200', 'CLASSIFICATION_C2000',
#        'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000', 'CLASSIFICATION_Other',
#        'USE_CASE_CommunityServ', 'USE_CASE_Heathcare', 'USE_CASE_Other',
#        'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
#        'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
#        'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M'],
#       dtype='object')

# %%
#Input dimensions
print(len(application_df_get_dummies.columns))
# Out:
# 40

# %%
application_df_concat = pd.concat([application_df, application_df_get_dummies], axis=1)
application_df_concat_list = application_df_concat.columns.tolist()
application_df_concat_list
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'ASK_AMT',
#  'ASK_AMT',
#  'APPLICATION_TYPE_Other',
#  'APPLICATION_TYPE_T10',
#  'APPLICATION_TYPE_T19',
#  'APPLICATION_TYPE_T3',
#  'APPLICATION_TYPE_T4',
#  'APPLICATION_TYPE_T5',
#  'APPLICATION_TYPE_T6',
#  'APPLICATION_TYPE_T7',
#  'APPLICATION_TYPE_T8',
#  'AFFILIATION_CompanySponsored',
#  'AFFILIATION_Family/Parent',
#  'AFFILIATION_Independent',
#  'AFFILIATION_National',
#  'AFFILIATION_Other',
#  'AFFILIATION_Regional',
#  'CLASSIFICATION_C1000',
#  'CLASSIFICATION_C1200',
#  'CLASSIFICATION_C2000',
#  'CLASSIFICATION_C2100',
#  'CLASSIFICATION_C3000',
#  'CLASSIFICATION_Other',
#  'USE_CASE_CommunityServ',
#  'USE_CASE_Heathcare',
#  'USE_CASE_Other',
#  'USE_CASE_Preservation',
#  'USE_CASE_ProductDev',
#  'ORGANIZATION_Association',
#  'ORGANIZATION_Co-operative',
#  'ORGANIZATION_Corporation',
#  'ORGANIZATION_Trust',
#  'INCOME_AMT_0',
#  'INCOME_AMT_1-9999',
#  'INCOME_AMT_10000-24999',
#  'INCOME_AMT_100000-499999',
#  'INCOME_AMT_10M-50M',
#  'INCOME_AMT_1M-5M',
#  'INCOME_AMT_25000-99999',
#  'INCOME_AMT_50M+',
#  'INCOME_AMT_5M-10M']

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = application_df_get_dummies.values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train and Evaluate the Model

# %% [markdown]
# Attempt 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=40))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=6, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 246
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 295
# Trainable params: 295
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 881us/step - loss: 0.6345 - accuracy: 0.6819
# Epoch 2/100
# 804/804 [==============================] - 1s 668us/step - loss: 0.5819 - accuracy: 0.7168
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5680 - accuracy: 0.7239
# Epoch 4/100
# 804/804 [==============================] - 1s 971us/step - loss: 0.5628 - accuracy: 0.7259
# Epoch 5/100
# 804/804 [==============================] - 1s 674us/step - loss: 0.5595 - accuracy: 0.7273
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5573 - accuracy: 0.7280
# Epoch 7/100
# 804/804 [==============================] - 1s 686us/step - loss: 0.5553 - accuracy: 0.7289
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5543 - accuracy: 0.7285
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5535 - accuracy: 0.7281
# Epoch 10/100
# 804/804 [==============================] - 1s 879us/step - loss: 0.5529 - accuracy: 0.7298
# Epoch 11/100
# 804/804 [==============================] - 1s 684us/step - loss: 0.5527 - accuracy: 0.7298
# Epoch 12/100
# 804/804 [==============================] - 1s 902us/step - loss: 0.5520 - accuracy: 0.7292
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7317
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5514 - accuracy: 0.7303
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7294
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7323
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7305
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5503 - accuracy: 0.7313
# Epoch 20/100
# 804/804 [==============================] - 1s 995us/step - loss: 0.5504 - accuracy: 0.7307
# Epoch 21/100
# 804/804 [==============================] - 1s 918us/step - loss: 0.5501 - accuracy: 0.7304
# Epoch 22/100
# 804/804 [==============================] - 1s 719us/step - loss: 0.5501 - accuracy: 0.7312
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5502 - accuracy: 0.7311
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5498 - accuracy: 0.7318
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5496 - accuracy: 0.7303
# Epoch 26/100
# 804/804 [==============================] - 1s 965us/step - loss: 0.5496 - accuracy: 0.7302
# Epoch 27/100
# 804/804 [==============================] - 1s 949us/step - loss: 0.5496 - accuracy: 0.7310
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7318
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7325
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7323
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7322
# Epoch 32/100
# 804/804 [==============================] - 1s 742us/step - loss: 0.5491 - accuracy: 0.7325
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7311
# Epoch 34/100
# 804/804 [==============================] - 1s 956us/step - loss: 0.5490 - accuracy: 0.7308
# Epoch 35/100
# 804/804 [==============================] - 1s 732us/step - loss: 0.5489 - accuracy: 0.7315
# Epoch 36/100
# 804/804 [==============================] - 1s 810us/step - loss: 0.5491 - accuracy: 0.7318
# Epoch 37/100
# 804/804 [==============================] - 1s 720us/step - loss: 0.5490 - accuracy: 0.7311
# Epoch 38/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5489 - accuracy: 0.7317
# Epoch 39/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5487 - accuracy: 0.7317
# Epoch 40/100
# 804/804 [==============================] - 1s 886us/step - loss: 0.5488 - accuracy: 0.73220s - loss: 0.5465
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5490 - accuracy: 0.7325
# Epoch 42/100
# 804/804 [==============================] - 1s 931us/step - loss: 0.5487 - accuracy: 0.7325
# Epoch 43/100
# 804/804 [==============================] - 1s 671us/step - loss: 0.5486 - accuracy: 0.7321
# Epoch 44/100
# 804/804 [==============================] - 1s 867us/step - loss: 0.5487 - accuracy: 0.7328
# Epoch 45/100
# 804/804 [==============================] - 1s 962us/step - loss: 0.5485 - accuracy: 0.7324
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7315: 0s - loss: 0.5471 - accuracy: 0.72 - ETA: 0s - loss: 0.5476 - ac
# Epoch 47/100
# 804/804 [==============================] - 1s 731us/step - loss: 0.5483 - accuracy: 0.73220s - loss: 0.5500 - accuracy
# Epoch 48/100
# 804/804 [==============================] - 1s 876us/step - loss: 0.5488 - accuracy: 0.7325
# Epoch 49/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5481 - accuracy: 0.7320
# Epoch 50/100
# 804/804 [==============================] - 1s 887us/step - loss: 0.5482 - accuracy: 0.7317
# Epoch 51/100
# 804/804 [==============================] - 1s 992us/step - loss: 0.5480 - accuracy: 0.7322
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7326
# Epoch 53/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5481 - accuracy: 0.7332
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5481 - accuracy: 0.7325
# Epoch 55/100
# 804/804 [==============================] - 1s 949us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 56/100
# 804/804 [==============================] - 1s 967us/step - loss: 0.5478 - accuracy: 0.7332
# Epoch 57/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5479 - accuracy: 0.7333
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7330
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5477 - accuracy: 0.7329
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5478 - accuracy: 0.7328
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5478 - accuracy: 0.7332
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5477 - accuracy: 0.7323
# Epoch 63/100
# 804/804 [==============================] - 1s 909us/step - loss: 0.5476 - accuracy: 0.73190s - loss: 0.539
# Epoch 64/100
# 804/804 [==============================] - 1s 872us/step - loss: 0.5476 - accuracy: 0.7327
# Epoch 65/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5475 - accuracy: 0.7320
# Epoch 66/100
# 804/804 [==============================] - 0s 612us/step - loss: 0.5475 - accuracy: 0.7332
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7332
# Epoch 68/100
# 804/804 [==============================] - 1s 910us/step - loss: 0.5474 - accuracy: 0.7326
# Epoch 69/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5472 - accuracy: 0.7329
# Epoch 70/100
# 804/804 [==============================] - 1s 651us/step - loss: 0.5478 - accuracy: 0.7326
# Epoch 71/100
# 804/804 [==============================] - 1s 936us/step - loss: 0.5472 - accuracy: 0.7330
# Epoch 72/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5474 - accuracy: 0.7332
# Epoch 73/100
# 804/804 [==============================] - 1s 917us/step - loss: 0.5473 - accuracy: 0.7329
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7338
# Epoch 75/100
# 804/804 [==============================] - 1s 923us/step - loss: 0.5474 - accuracy: 0.7320
# Epoch 76/100
# 804/804 [==============================] - 1s 733us/step - loss: 0.5475 - accuracy: 0.7336
# Epoch 77/100
# 804/804 [==============================] - 1s 745us/step - loss: 0.5473 - accuracy: 0.7327
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7319
# Epoch 79/100
# 804/804 [==============================] - 1s 705us/step - loss: 0.5472 - accuracy: 0.7330
# Epoch 80/100
# 804/804 [==============================] - 1s 990us/step - loss: 0.5473 - accuracy: 0.7334
# Epoch 81/100
# 804/804 [==============================] - 1s 658us/step - loss: 0.5471 - accuracy: 0.7324
# Epoch 82/100
# 804/804 [==============================] - 1s 852us/step - loss: 0.5473 - accuracy: 0.7325
# Epoch 83/100
# 804/804 [==============================] - 1s 751us/step - loss: 0.5470 - accuracy: 0.7331
# Epoch 84/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5470 - accuracy: 0.7334
# Epoch 85/100
# 804/804 [==============================] - 1s 669us/step - loss: 0.5472 - accuracy: 0.7339
# Epoch 86/100
# 804/804 [==============================] - 1s 833us/step - loss: 0.5469 - accuracy: 0.7339
# Epoch 87/100
# 804/804 [==============================] - 0s 615us/step - loss: 0.5471 - accuracy: 0.7329
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7327
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7335
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7330
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7332
# Epoch 92/100
# 804/804 [==============================] - 1s 648us/step - loss: 0.5471 - accuracy: 0.7329
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7327
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5468 - accuracy: 0.7336: 0s
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5468 - accuracy: 0.7330
# Epoch 96/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5472 - accuracy: 0.73330s - loss: 0.5499 - ac
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7333
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5470 - accuracy: 0.7336
# Epoch 99/100
# 804/804 [==============================] - 1s 904us/step - loss: 0.5470 - accuracy: 0.7337
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5468 - accuracy: 0.7343

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_train_scaled,y_train,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 804/804 - 1s - loss: 0.5468 - accuracy: 0.7343
# Loss: 0.5467948913574219, Accuracy: 0.7342559695243835

# %% [markdown]
# Attempt 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=10, activation="relu", input_dim=43))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=10, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                440
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 561
# Trainable params: 561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 25724/25724 [==============================] - 1s 37us/sample - loss: 0.6239 - acc: 0.6808
# Epoch 2/200
# 25724/25724 [==============================] - 1s 36us/sample - loss: 0.5689 - acc: 0.7251
# Epoch 3/200
# 25724/25724 [==============================] - 1s 31us/sample - loss: 0.5604 - acc: 0.7284
# Epoch 4/200
# 25724/25724 [==============================] - 1s 28us/sample - loss: 0.5557 - acc: 0.7296
# Epoch 5/200
# 25724/25724 [==============================] - 1s 31us/sample - loss: 0.5539 - acc: 0.7317
# Epoch 6/200
# 25724/25724 [==============================] - 1s 40us/sample - loss: 0.
200
# 25724/25724 [==============================] - 1s 54us/sample - loss: 0.5382 - acc: 0.7397
# Epoch 194/200
# 25724/25724 [==============================] - 1s 50us/sample - loss: 0.5376 - acc: 0.7400
# Epoch 195/200
# 25724/25724 [==============================] - 1s 53us/sample - loss: 0.5377 - acc: 0.7404
# Epoch 196/200
# 25724/25724 [==============================] - 1s 42us/sample - loss: 0.5378 - acc: 0.7395
# Epoch 197/200
# 25724/25724 [==============================] - 1s 43us/sample - loss: 0.5379 - acc: 0.7403
# Epoch 198/200
# 25724/25724 [==============================] - 1s 43us/sample - loss: 0.5376 - acc: 0.7386
# Epoch 199/200
# 25724/25724 [==============================] - 1s 41us/sample - loss: 0.5376 - acc: 0.7400
# Epoch 200/200
# 25724/25724 [==============================] - 1s 38us/sample - loss: 0.5380 - acc: 0.7392

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_train_scaled,y_train,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 25724/25724 - 0s - loss: 0.5354 - acc: 0.7408
# Loss: 0.5354323680488712, Accuracy: 0.7408257126808167

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\untitled_project\oracle.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# relu              |?                 |activation
# 7                 |?                 |first_units
# 3                 |?                 |num_layers
# 9                 |?                 |units_0
# 3                 |?                 |tuner/epochs
# 0                 |?                 |tuner/initial_epoch
# 2                 |?                 |tuner/bracket
# 0                 |?                 |tuner/round
#
# Train on 25724 samples, validate on 8575 samples
# Epoch 1/3
# 25024/25724 [============================>.] - ETA: 0s - loss: 0.6915 - acc: 0.5324
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16576\1874305172.py in <module>
#       1 # Run the kerastuner search for best hyperparameters
# ----> 2 tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     181
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#     185             if results is None:
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\tuners\hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     382             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     383             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384         return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     385
#     386     def _build_model(self, hp):
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     293             callbacks.append(model_checkpoint)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#     297             histories.append(obj_value)
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     220         hp = trial.hyperparameters
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#     224             results, self.oracle.objective, "HyperModel.fit()"
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     138             If return a float, it should be the `objective` value.
#     139         """
# --> 140         return model.fit(*args, **kwargs)
#     141
#     142
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
#     779           validation_freq=validation_freq,
# --> 780           steps_name='steps_per_epoch')
#     781
#     782   def evaluate(self,
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     417     if mode == ModeKeys.TRAIN:
#     418       # Epochs only apply to `fit`.
# --> 419       callbacks.on_epoch_end(epoch, epoch_logs)
#     420     progbar.on_epoch_end(epoch, epoch_logs)
#     421
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     309     logs = logs or {}
#     310     for callback in self.callbacks:
# --> 311       callback.on_epoch_end(epoch, logs)
#     312
#     313   def on_train_batch_begin(self, batch, logs=None):
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\tuner_utils.py in on_epoch_end(self, epoch, logs)
#     208             # objective is specified, or objective is computed and returned
#     209             # after `fit()`.
# --> 210             self._save_model()
#     211             return
#     212         current_value = self.objective.get_value(logs)
#
# ~\anaconda3\anacondatake2\envs\PythonData\lib\site-packages\keras_tuner\engine\tuner_utils.py in _save_model(self)
#     218         # Create temporary saved model files on non-chief workers.
#     219         write_filepath = ds_utils.write_filepath(
# --> 220             self.filepath, self.model.distribute_strategy
#     221         )
#     222         self.model.save_weights(write_filepath)
#
# AttributeError: 'Sequential' object has no attribute 'distribute_strategy'

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
